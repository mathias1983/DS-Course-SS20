# %%
import numpy as np
# to make this notebook's output stable across runs
np.random.seed(42)
# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# %%
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
iris = datasets.load_iris()

# %%
## first feature
X = iris["data"][:, 0].reshape((-1,1))  # petal width
y = (iris["target"] == 2).astype(np.int)  # 1 if Iris-Virginica, else 0
log_reg = LogisticRegression(random_state=42)
log_reg.fit(X, y)
X_new = np.linspace(4, 8, 1000).reshape(-1, 1)
y_proba = log_reg.predict_proba(X_new)
plt.plot(X_new, y_proba[:, 1], "g-", linewidth=2, label="Iris-Virginica")
plt.plot(X_new, y_proba[:, 0], "b--", linewidth=2, label="Not Iris-Virginica")

# %%
print("Probability first feature 4.8: ",log_reg.predict_proba([[4.8]])[:,1])
# Out:
# Probability first feature 4.8:  [0.03237634]

# %%
## second feature
X = iris["data"][:, 1].reshape((-1,1))  # petal width
y = (iris["target"] == 2).astype(np.int)  # 1 if Iris-Virginica, else 0
log_reg = LogisticRegression(random_state=42)
log_reg.fit(X, y)
X_new = np.linspace(0, 5, 1000).reshape(-1, 1)
y_proba = log_reg.predict_proba(X_new)
plt.plot(X_new, y_proba[:, 1], "g-", linewidth=2, label="Iris-Virginica")
plt.plot(X_new, y_proba[:, 0], "b--", linewidth=2, label="Not Iris-Virginica")

# %%
print("Probability second feature 2.5: ",log_reg.predict_proba([[2.5]])[:,1])
# Out:
# Probability second feature 2.5:  [0.4066497]

# %%
## third feature
X = iris["data"][:, 2].reshape((-1,1))  # petal width
y = (iris["target"] == 2).astype(np.int)  # 1 if Iris-Virginica, else 0
log_reg = LogisticRegression(random_state=42)
log_reg.fit(X, y)
X_new = np.linspace(3, 7, 1000).reshape(-1, 1)
y_proba = log_reg.predict_proba(X_new)
plt.plot(X_new, y_proba[:, 1], "g-", linewidth=2, label="Iris-Virginica")
plt.plot(X_new, y_proba[:, 0], "b--", linewidth=2, label="Not Iris-Virginica")

# %%
print("Probability third feature 5.3: ",log_reg.predict_proba([[5.3]])[:,1])
# Out:
# Probability third feature 5.3:  [0.82089909]

# %%
## fourth feature
X = iris["data"][:, 3].reshape((-1,1))  # petal width
y = (iris["target"] == 2).astype(np.int)  # 1 if Iris-Virginica, else 0
log_reg = LogisticRegression(random_state=42)
log_reg.fit(X, y)
X_new = np.linspace(1, 3, 1000).reshape(-1, 1)
y_proba = log_reg.predict_proba(X_new)
plt.plot(X_new, y_proba[:, 1], "g-", linewidth=2, label="Iris-Virginica")
plt.plot(X_new, y_proba[:, 0], "b--", linewidth=2, label="Not Iris-Virginica")

# %%
print("Probability fourth feature 2.4: ",log_reg.predict_proba([[2.4]])[:,1])
# Out:
# Probability fourth feature 2.4:  [0.96101057]
